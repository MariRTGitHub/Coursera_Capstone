# %%
import pandas as pd

# %%
import numpy as np

# %%
print ()'¡Hola, Proyecto Final del Curso!'
# Out:
#   File "/tmp/wsuser/ipykernel_164/1760950214.py", line 1
#     print '¡Hola, Proyecto Final del Curso!'
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print('¡Hola, Proyecto Final del Curso!')?
